MB/s eta 0:00:00
# Downloading kiwisolver-1.4.5-cp312-cp312-win_amd64.whl (56 kB)
#    ---------------------------------------- 0.0/56.0 kB ? eta -:--:--
#    ---------------------------------------- 56.0/56.0 kB 2.9 MB/s eta 0:00:00
# Downloading pyparsing-3.1.4-py3-none-any.whl (104 kB)
#    ---------------------------------------- 0.0/104.1 kB ? eta -:--:--
#    ---------------------------------------- 104.1/104.1 kB ? eta 0:00:00
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib, seaborn
# Successfully installed contourpy-1.2.1 cycler-0.12.1 fonttools-4.53.1 kiwisolver-1.4.5 matplotlib-3.9.2 pyparsing-3.1.4 seaborn-0.13.2
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# import librarires:
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mysql.connector
import numpy as np

# %%
#Customer Table
# load customer table
path=r"C:\Users\ukudh\OneDrive\Desktop\MDTE11\Project\DataSpark\Customers.csv"

# %%
df_customers=pd.read_csv(path,encoding='latin-1')
df_customers
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
#                    State Zip Code        Country      Continent    Birthday
# 0        South Australia     5523      Australia      Australia    7/3/1939
# 1      Western Australia     6522      Australia      Australia   9/27/1979
# 2               Victoria     3380      Australia      Australia   5/26/1947
# 3        South Australia     5223      Australia      Australia   9/17/1957
# 4               Victoria     3698      Australia      Australia  11/19/1965
# ...                  ...      ...            ...            ...         ...
# 15261              Texas    77017  United States  North America   3/25/1936
# 15262           Virginia    22101  United States  North America   2/16/1992
# 15263     North Carolina    28405  United States  North America   11/9/1937
# 15264         California    92501  United States  North America  10/12/1937
# 15265           Michigan    48302  United States  North America   8/18/1965
#
# [15266 rows x 10 columns]

# %%
df_customers['Birthday'] = pd.to_datetime(df_customers['Birthday'], format="%m/%d/%Y", errors='coerce').dt.date
df_customers
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
#                    State Zip Code        Country      Continent    Birthday
# 0        South Australia     5523      Australia      Australia  1939-07-03
# 1      Western Australia     6522      Australia      Australia  1979-09-27
# 2               Victoria     3380      Australia      Australia  1947-05-26
# 3        South Australia     5223      Australia      Australia  1957-09-17
# 4               Victoria     3698      Australia      Australia  1965-11-19
# ...                  ...      ...            ...            ...         ...
# 15261              Texas    77017  United States  North America  1936-03-25
# 15262           Virginia    22101  United States  North America  1992-02-16
# 15263     North Carolina    28405  United States  North America  1937-11-09
# 15264         California    92501  United States  North America  1937-10-12
# 15265           Michigan    48302  United States  North America  1965-08-18
#
# [15266 rows x 10 columns]

# %%
#check data types
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15266 entries, 0 to 15265
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CustomerKey  15266 non-null  int64
#  1   Gender       15266 non-null  object
#  2   Name         15266 non-null  object
#  3   City         15266 non-null  object
#  4   State Code   15256 non-null  object
#  5   State        15266 non-null  object
#  6   Zip Code     15266 non-null  object
#  7   Country      15266 non-null  object
#  8   Continent    15266 non-null  object
#  9   Birthday     15266 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 1.2+ MB

# %%
# check missing values
df_customers.isnull().sum()
# Out:
# CustomerKey     0
# Gender          0
# Name            0
# City            0
# State Code     10
# State           0
# Zip Code        0
# Country         0
# Continent       0
# Birthday        0
# dtype: int64

# %%
# drop the missing values
df_customers.dropna(inplace=True)
df_customers.isnull().sum()
# Out:
# CustomerKey    0
# Gender         0
# Name           0
# City           0
# State Code     0
# State          0
# Zip Code       0
# Country        0
# Continent      0
# Birthday       0
# dtype: int64

# %%
# visualize country counts
plt.figure(figsize=(12,5))
sns.countplot(x=df_customers["Country"],data=df_customers,hue="Country")
plt.xlabel("Country")
plt.ylabel("counts")
plt.title("counts as per Country")
# Out:
# Text(0.5, 1.0, 'counts as per Country')

# %%
# visualize gender details
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
plt.pie(df_customers["Gender"].value_counts(), 
        autopct='%1.0f%%', 
        labels=['Male', 'Female'])
plt.subplot(2,2,2)
sns.countplot(x=df_customers["Gender"],data=df_customers,hue="Gender")
plt.xlabel("Gender")
plt.ylabel("counts")
plt.title("counts as per Gender")
plt.show()

# %%
# drop the columns
df_customers.drop(["State Code","Zip Code"],axis=1,inplace=True)

# %%
#Exchange Rates:
# load exchange table
path=r"C:\Users\ukudh\OneDrive\Desktop\MDTE11\Project\DataSpark\Exchange_Rates.csv"

# %%
df_exchange=pd.read_csv(path)
df_exchange
# Out:
#             Date Currency  Exchange
# 0       1/1/2015      USD    1.0000
# 1       1/1/2015      CAD    1.1583
# 2       1/1/2015      AUD    1.2214
# 3       1/1/2015      EUR    0.8237
# 4       1/1/2015      GBP    0.6415
# ...          ...      ...       ...
# 11210  2/20/2021      USD    1.0000
# 11211  2/20/2021      CAD    1.2610
# 11212  2/20/2021      AUD    1.2723
# 11213  2/20/2021      EUR    0.8238
# 11214  2/20/2021      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
# rename the column
df_exchange.rename(columns={"Currency":"Currency Code"},inplace=True)
df_exchange['Date'] = pd.to_datetime(df_exchange['Date'], format="%m/%d/%Y", errors='coerce')

# %%
#check data types
df_exchange.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11215 entries, 0 to 11214
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           11215 non-null  datetime64[ns]
#  1   Currency Code  11215 non-null  object
#  2   Exchange       11215 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 263.0+ KB

# %%
# check missing values
df_exchange.isnull().sum()
# Out:
# Date             0
# Currency Code    0
# Exchange         0
# dtype: int64

# %%
# visualize currency counts
plt.figure(figsize=(12,5))
sns.countplot(x=df_exchange["Currency Code"],data=df_exchange,hue="Currency Code")
plt.xlabel("Currency Code")
plt.ylabel("counts")
plt.title("counts as per Currency Code")
# Out:
# Text(0.5, 1.0, 'counts as per Currency Code')

# %%
#Products:
# load products table
path=r"C:\Users\ukudh\OneDrive\Desktop\MDTE11\Project\DataSpark\Products.csv"

# %%
df_products=pd.read_csv(path)
df_products
# Out:
#       ProductKey                                   Product Name    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color Unit Cost USD Unit Price USD  SubcategoryKey  \
# 0     Silver        $6.62         $12.99              101
# 1       Blue        $6.62         $12.99              101
# 2      White        $7.40         $14.52              101
# 3     Silver       $11.00         $21.57              101
# 4        Red       $11.00         $21.57              101
# ...      ...           ...            ...             ...
# 2512     Red       $43.07        $129.99              505
# 2513   White       $43.07        $129.99              505
# 2514   White        $1.71          $3.35              505
# 2515   Black        $1.71          $3.35              505
# 2516  Silver        $1.71          $3.35              505
#
#                   Subcategory  CategoryKey     Category
# 0                     MP4&MP3            1        Audio
# 1                     MP4&MP3            1        Audio
# 2                     MP4&MP3            1        Audio
# 3                     MP4&MP3            1        Audio
# 4                     MP4&MP3            1        Audio
# ...                       ...          ...          ...
# 2512  Cell phones Accessories            5  Cell phones
# 2513  Cell phones Accessories            5  Cell phones
# 2514  Cell phones Accessories            5  Cell phones
# 2515  Cell phones Accessories            5  Cell phones
# 2516  Cell phones Accessories            5  Cell phones
#
# [2517 rows x 10 columns]

# %%
#check data types
df_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ProductKey      2517 non-null   int64
#  1   Product Name    2517 non-null   object
#  2   Brand           2517 non-null   object
#  3   Color           2517 non-null   object
#  4   Unit Cost USD   2517 non-null   object
#  5   Unit Price USD  2517 non-null   object
#  6   SubcategoryKey  2517 non-null   int64
#  7   Subcategory     2517 non-null   object
#  8   CategoryKey     2517 non-null   int64
#  9   Category        2517 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 196.8+ KB

# %%
# check missing values
df_products.isnull().sum()
# Out:
# ProductKey        0
# Product Name      0
# Brand             0
# Color             0
# Unit Cost USD     0
# Unit Price USD    0
# SubcategoryKey    0
# Subcategory       0
# CategoryKey       0
# Category          0
# dtype: int64

# %%
df_products["Unit Cost USD"] = df_products["Unit Cost USD"].str.replace("$", "").str.replace(",", "")
df_products["Unit Cost USD"] = df_products["Unit Cost USD"].astype(float)

df_products["Unit Price USD"] = df_products["Unit Price USD"].str.replace("$", "").str.replace(",", "")
df_products["Unit Price USD"] = df_products["Unit Price USD"].astype(float)

# %%
df_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ProductKey      2517 non-null   int64
#  1   Product Name    2517 non-null   object
#  2   Brand           2517 non-null   object
#  3   Color           2517 non-null   object
#  4   Unit Cost USD   2517 non-null   float64
#  5   Unit Price USD  2517 non-null   float64
#  6   SubcategoryKey  2517 non-null   int64
#  7   Subcategory     2517 non-null   object
#  8   CategoryKey     2517 non-null   int64
#  9   Category        2517 non-null   object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 196.8+ KB

# %%
#visualize the brand and category
plt.figure(figsize=(50,8))
plt.subplot(1,2,1)
sns.countplot(x=df_products["Brand"],data=df_products,hue="Brand")
plt.xlabel("Brand")
plt.ylabel("counts")
plt.title("counts as per Brand")
plt.show()
plt.figure(figsize=(40,8))
plt.subplot(2,2,2)
sns.countplot(x=df_products["Category"],data=df_products,hue="Category")
plt.xlabel("Category")
plt.ylabel("counts")
plt.title("counts as per Category")
plt.show()

# %%
#Sales:
path=r"C:\Users\ukudh\OneDrive\Desktop\MDTE11\Project\DataSpark\Sales.csv"

# %%
df_sales=pd.read_csv(path)
df_sales
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 0            366000          1   1/1/2016           NaN       265598
# 1            366001          1   1/1/2016     1/13/2016      1269051
# 2            366001          2   1/1/2016     1/13/2016      1269051
# 3            366002          1   1/1/2016     1/12/2016       266019
# 4            366002          2   1/1/2016     1/12/2016       266019
# ...             ...        ...        ...           ...          ...
# 62879       2243030          1  2/20/2021           NaN      1216913
# 62880       2243031          1  2/20/2021     2/24/2021       511229
# 62881       2243032          1  2/20/2021     2/23/2021       331277
# 62882       2243032          2  2/20/2021     2/23/2021       331277
# 62883       2243032          3  2/20/2021     2/23/2021       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# 1             0        1048         2           USD
# 2             0        2007         1           USD
# 3             0        1106         7           CAD
# 4             0         373         1           CAD
# ...         ...         ...       ...           ...
# 62879        43         632         3           USD
# 62880         0          98         4           EUR
# 62881         0        1613         2           CAD
# 62882         0        1717         2           CAD
# 62883         0         464         7           CAD
#
# [62884 rows x 9 columns]

# %%
#check data types
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62884 entries, 0 to 62883
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order Number   62884 non-null  int64
#  1   Line Item      62884 non-null  int64
#  2   Order Date     62884 non-null  object
#  3   Delivery Date  13165 non-null  object
#  4   CustomerKey    62884 non-null  int64
#  5   StoreKey       62884 non-null  int64
#  6   ProductKey     62884 non-null  int64
#  7   Quantity       62884 non-null  int64
#  8   Currency Code  62884 non-null  object
# dtypes: int64(6), object(3)
# memory usage: 4.3+ MB

# %%
# check missing values
df_sales.isnull().sum()
# Out:
# Order Number         0
# Line Item            0
# Order Date           0
# Delivery Date    49719
# CustomerKey          0
# StoreKey             0
# ProductKey           0
# Quantity             0
# Currency Code        0
# dtype: int64

# %%
df_sales['Order Date'] = pd.to_datetime(df_sales['Order Date'], format="%m/%d/%Y", errors='coerce').dt.date

# %%
# fill the missing values
df_sales["Delivery Date"]=df_sales["Delivery Date"].fillna(0)

# %%
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62884 entries, 0 to 62883
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order Number   62884 non-null  int64
#  1   Line Item      62884 non-null  int64
#  2   Order Date     62884 non-null  object
#  3   Delivery Date  62884 non-null  object
#  4   CustomerKey    62884 non-null  int64
#  5   StoreKey       62884 non-null  int64
#  6   ProductKey     62884 non-null  int64
#  7   Quantity       62884 non-null  int64
#  8   Currency Code  62884 non-null  object
# dtypes: int64(6), object(3)
# memory usage: 4.3+ MB

# %%
#Stores:
path=r"C:\Users\ukudh\OneDrive\Desktop\MDTE11\Project\DataSpark\Stores.csv"

# %%
df_stores=pd.read_csv(path)
df_stores
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            NaN
#
#     Open Date
# 0    1/1/2008
# 1   1/12/2008
# 2    1/7/2012
# 3    1/1/2010
# 4   12/9/2015
# ..        ...
# 62   3/6/2008
# 63   1/1/2010
# 64   1/1/2012
# 65   1/1/2014
# 66   1/1/2010
#
# [67 rows x 5 columns]

# %%
df_stores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   StoreKey       67 non-null     int64
#  1   Country        67 non-null     object
#  2   State          67 non-null     object
#  3   Square Meters  66 non-null     float64
#  4   Open Date      67 non-null     object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 2.7+ KB

# %%
# check missing values
df_stores.isnull().sum()
# Out:
# StoreKey         0
# Country          0
# State            0
# Square Meters    1
# Open Date        0
# dtype: int64

# %%
df_stores.fillna(0)
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            0.0
#
#     Open Date
# 0    1/1/2008
# 1   1/12/2008
# 2    1/7/2012
# 3    1/1/2010
# 4   12/9/2015
# ..        ...
# 62   3/6/2008
# 63   1/1/2010
# 64   1/1/2012
# 65   1/1/2014
# 66   1/1/2010
#
# [67 rows x 5 columns]

# %%
df_stores['Open Date'] = pd.to_datetime(df_stores['Open Date'], format="%m/%d/%Y", errors='coerce').dt.date

# %%
# replacing the nan value
df_stores = df_stores.replace({np.nan: None})

# %%
df_stores["Square Meters"]=df_stores["Square Meters"].fillna(0)
# Out:
# C:\Users\ukudh\AppData\Local\Temp\ipykernel_3704\927198854.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_stores["Square Meters"]=df_stores["Square Meters"].fillna(0)

# %%
df_stores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   StoreKey       67 non-null     int64
#  1   Country        67 non-null     object
#  2   State          67 non-null     object
#  3   Square Meters  67 non-null     float64
#  4   Open Date      67 non-null     object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 2.7+ KB

# %%
#Create SQL Database:
import mysql.connector
mydb = mysql.connector.connect(
 host="localhost",
 user="root",
 password="Ramya@9198",


)


print(mydb)
mycursor = mydb.cursor(buffered=True)
# Out:
# <mysql.connector.connection_cext.CMySQLConnection object at 0x000002D440248200>

# %%
mycursor.execute("CREATE DATABASE  customer_sales")

# %%
#sql connection
conn=mysql.connector.connect(host="localhost", user="root", password="Ramya@9198",database="customer_sales")
mycursor = conn.cursor()
mycursor.execute("CREATE DATABASE IF NOT EXISTS customer_sales")
print("database created successfully")
# Out:
# database created successfully

# %%
#customer table creation
mycursor.execute('''CREATE TABLE IF NOT EXISTS customer_details(
                  CustomerKey INT,
                  Gender VARCHAR(255),
                  Name VARCHAR(255),
                  City VARCHAR(255),
                  State VARCHAR(255),
                  Country VARCHAR(255),
                  Continent VARCHAR(255),
                  Birthday VARCHAR(255)
                  )''')
print("Table Created successfully")
# Out:
# Table Created successfully

# %%
# insert values into customer table
insert_query='''INSERT INTO customer_sales.customer_details(
                  CustomerKey,
                  Gender,
                  Name,
                  City,
                  State,
                  Country,
                  Continent,
                  Birthday)
                  VALUES(%s,%s,%s,%s,%s,%s,%s,%s)'''
for index, row in df_customers.iterrows():
    mycursor.execute(insert_query, (
        row['CustomerKey'], row['Gender'],
        row['Name'], row['City'], 
        row['State'], 
        row['Country'], row['Continent'], row['Birthday']
        
    ))
#data=df_customers.values.tolist()
#mycursor.executemany(insert_query,data)
print("Inserted successfully")
# Out:
# Inserted successfully

# %%
mycursor.execute("select * from customer_sales.customer_details")
print(list(mycursor.description))
# Out:
# [('CustomerKey', 3, None, None, None, None, 1, 32768, 63), ('Gender', 253, None, None, None, None, 1, 0, 255), ('Name', 253, None, None, None, None, 1, 0, 255), ('City', 253, None, None, None, None, 1, 0, 255), ('State', 253, None, None, None, None, 1, 0, 255), ('Country', 253, None, None, None, None, 1, 0, 255), ('Continent', 253, None, None, None, None, 1, 0, 255), ('Birthday', 253, None, None, None, None, 1, 0, 255)]

# %%
for x in mycursor:
    print(x)
# Out:
# (301, 'Female', 'Lilly Harding', 'WANDEARAH EAST', 'South Australia', 'Australia', 'Australia', '1939-7-3')
# (325, 'Female', 'Madison Hull', 'MOUNT BUDD', 'Western Australia', 'Australia', 'Australia', '1979-9-27')
# (554, 'Female', 'Claire Ferres', 'WINJALLOK', 'Victoria', 'Australia', 'Australia', '1947-5-26')
# (786, 'Male', 'Jai Poltpalingada', 'MIDDLE RIVER', 'South Australia', 'Australia', 'Australia', '1957-9-17')
# (1042, 'Male', 'Aidan Pankhurst', 'TAWONGA SOUTH', 'Victoria', 'Australia', 'Australia', '1965-11-19')
# (1086, 'Male', 'Hayden Clegg', 'TEMPLERS', 'South Australia', 'Australia', 'Australia', '1954-1-20')
# (1133, 'Male', 'Nicholas Caffyn', 'JUBILEE POCKET', 'Queensland', 'Australia', 'Australia', '1969-11-22')
# (1256, 'Male', 'Lincoln Jenks', 'KULLOGUM', 'Queensland', 'Australia', 'Australia', '1950-3-12')
# (1314, 'Male', 'Isaac Israel', 'EDITH RIVER', 'Northern Territory', 'Australia', 'Australia', '1965-12-21')
# (1568, 'Male', 'Luke Virtue', 'KOTTA', 'Victoria', 'Australia', 'Australia', '1975-7-25')
# (1585, 'Female', 'Anna Hallstrom', 'GREEN LAKE', 'Victoria', 'Australia', 'Australia', '1990-8-12')
# (1626, 'Female', 'Mary Leach', 'NEDS CORNER', 'Victoria', 'Australia', 'Australia', '1985-10-17')
# (1642, 'Female', 'Ruby Ambrose', 'TARLO', 'New South Wales', 'Australia', 'Australia', '1965-3-3')
# (1677, 'Male', 'Dean Innes', 'ELLESMERE', 'Queensland', 'Australia', 'Australia', '1964-11-22')
# (1817, 'Female', 'Laura Le Rennetel', 'BEAUCHAMP', 'Victoria', 'Australia', 'Australia', '1986-7-10')
# (1863, 'Female', 'Chelsea Watkins', 'NAMBOUR DC', 'Queensland', 'Australia', 'Australia', '1984-9-22')
# (1945, 'Male', 'Angus Beaurepaire', 'GREENFIELDS', 'Western Australia', 'Australia', 'Australia', '1974-9-20')
# (2238, 'Female', 'Isabelle Cochran', 'BRUCKNELL', 'Victoria', 'Australia', 'Australia', '1969-10-31')
# (2248, 'Male', 'Rory Spargo', 'JUNG', 'Victoria', 'Australia', 'Australia', '1987-12-15')
# (2435, 'Female', 'Lilian Hall', 'BLAKEBROOK', 'New South Wales', 'Australia', 'Australia', '1968-4-1')
# (2469, 'Female', 'Phoebe Kneeshaw', 'BIDWILL', 'Queensland', 'Australia', 'Australia', '1948-5-20')
# (2512, 'Female', 'Matilda Hake', 'BUNKERS HILL', 'Victoria', 'Australia', 'Australia', '1992-11-13')
# (2604, 'Female', 'Claudia Davison', 'KUBIN VILLAGE', 'Queensland', 'Australia', 'Australia', '1995-4-8')
# (2751, 'Male', 'Nate Lowes', 'CALLIDE', 'Queensland', 'Australia', 'Australia', '1979-8-20')
# (2792, 'Male', 'Zachary Perkin', 'BAMGANIE', 'Victoria', 'Australia', 'Australia', '1976-8-25')
# (2836, 'Male', 'Nicholas Shand', 'GORDONBROOK', 'Queensland', 'Australia', 'Australia', '1959-2-23')
# (3002, 'Male', 'Joshua Aronson', 'SMITHTON', 'Tasmania', 'Australia', 'Australia', '2000-11-8')
# (3006, 'Female', 'Alica Stuckey', 'HARTLEY', 'New South Wales', 'Australia', 'Australia', '1943-1-13')
# (3203, 'Male', 'Aidan Kane', 'ARGENTON', 'New South Wales', 'Australia', 'Australia', '1998-8-18')
# (3270, 'Male', 'Hunter Templeton', 'CENTRAL TILBA', 'New South Wales', 'Australia', 'Australia', '1948-5-2')
# (7700, 'Male', 'Lucas Keenan', 'STANWELL TOPS', 'New South Wales', 'Australia', 'Australia', '1975-1-27')
# (7725, 'Female', 'Anna Prerauer', 'CURRIMUNDI', 'Queensland', 'Australia', 'Australia', '1968-1-6')
# (7783, 'Female', 'Charli Gullett', 'MOUNT WALLACE', 'Victoria', 'Australia', 'Australia', '1961-8-13')
# (8098, 'Female', 'Alana Belt', 'SOUTH GREENOUGH', 'Western Australia', 'Australia', 'Australia', '1967-1-26')
# (8181, 'Female', 'Amelie Nairn', 'DARTMOUTH', 'Victoria', 'Australia', 'Australia', '1985-7-8')
# (8220, 'Male', 'David Blanch', 'Vista', 'South Australia', 'Australia', 'Australia', '1945-7-29')
# (8789, 'Female', 'Layla Mackellar', 'KALKARINDJI', 'Northern Territory', 'Australia', 'Australia', '1999-7-13')
# (8794, 'Female', 'Abbey Lempriere', 'BOULDER CREEK', 'Queensland', 'Australia', 'Australia', '1962-11-2')
# (8945, 'Female', 'Summer MacMahon', 'WARUMBUL', 'New South Wales', 'Australia', 'Australia', '1939-6-28')
# (9167, 'Male', 'Luke Bushby', 'PARACOMBE', 'South Australia', 'Australia', 'Australia', '1975-12-2')
# (9184, 'Male', 'Sam Zimpel', 'CORUNNUN', 'Victoria', 'Australia', 'Australia', '1964-11-24')
# (9360, 'Male', 'Mitchell Adam', 'MOPARRABAH', 'New South Wales', 'Australia', 'Australia', '1955-1-30')
# (9370, 'Female', 'Ruby Lock', 'Cook', 'Australian Capital Territory', 'Australia', 'Australia', '1953-5-26')
# (9389, 'Female', 'Eliza Brophy', 'YEARINAN', 'New South Wales', 'Australia', 'Australia', '1956-4-8')
# (9456, 'Male', 'Ryder Abdullah', 'CLAREDALE', 'Queensland', 'Australia', 'Australia', '1941-5-21')
# (9812, 'Female', 'Kaitlyn Morshead', 'MINJARY', 'New South Wales', 'Australia', 'Australia', '1953-1-23')
# (9915, 'Female', 'Ebony Buxton', 'SEPPINGS', 'Western Australia', 'Australia', 'Australia', '1991-11-10')
# (10039, 'Female', 'Brianna Hann', 'NIKENBAH', 'Queensland', 'Australia', 'Australia', '1947-10-22')
# (10189, 'Female', 'Alexis Birchell', 'FOREST REEFS', 'New South Wales', 'Australia', 'Australia', '1962-4-7')
# (10276, 'Male', 'Angus Bardolph', 'BATEAU BAY', 'New South Wales', 'Australia', 'Australia', '1972-11-1')
# (10299, 'Male', 'Anthony Macvitie', 'BEELBANGERA', 'New South Wales', 'Australia', 'Australia', '1937-5-27')
# (10332, 'Male', 'James Burnage', 'Palmyra', 'Western Australia', 'Australia', 'Australia', '1937-3-26')
# (10393, 'Male', 'Nicholas Moncrieff', 'ROSENTHAL HEIGHTS', 'Queensland', 'Australia', 'Australia', '1981-11-29')
# (10395, 'Male', 'Cameron Dillon', 'STRATHERNE', 'Western Australia', 'Australia', 'Australia', '1996-2-25')
# (10481, 'Female', 'Piper Maudsley', 'CELLS RIVER', 'New South Wales', 'Australia', 'Australia', '1977-4-17')
# (14275, 'Female', 'Dakota Dunshea', 'BENTLEY', 'New South Wales', 'Australia', 'Australia', '1979-5-2')
# (14906, 'Female', 'Grace Houghton', 'BOYER', 'Tasmania', 'Australia', 'Australia', '1982-11-16')
# (14962, 'Female', 'Mackenzie Newell', 'Crestwood', 'New South Wales', 'Australia', 'Australia', '1936-4-5')
# (14988, 'Female', 'Emily Thirkell', 'WYNDHAM VALE', 'Victoria', 'Australia', 'Australia', '1958-7-24')
# (15109, 'Female', 'Sara Marsden', 'WHALE BEACH', 'New South Wales', 'Australia', 'Australia', '1999-8-18')
# (15385, 'Male', 'Harry Morgans', 'DOONGIN', 'Western Australia', 'Australia', 'Australia', '1995-5-11')
# (15391, 'Female', 'Elizabeth Horsley', 'MARRAWEENEY', 'Victoria', 'Australia', 'Australia', '1989-1-25')
# (15569, 'Female', 'Chelsea Weekes', 'COLAC', 'Victoria', 'Australia', 'Australia', '1983-9-8')
# (15718, 'Female', 'Natalie Tennant', 'DAKENBA', 'Queensland', 'Australia', 'Australia', '1957-2-20')
# (16193, 'Female', 'Isabelle Beggs', 'ALTONA', 'South Australia', 'Australia', 'Australia', '1964-5-10')
# (16282, 'Female', 'Evie Kirkhope', 'REIDS FLAT', 'New South Wales', 'Australia', 'Australia', '2000-5-11')
# (16716, 'Female', 'Abby Frater', 'KAYUGA', 'New South Wales', 'Australia', 'Australia', '1987-12-16')
# (17412, 'Male', 'Mitchell Kwok', 'VICTORIA PARK', 'Western Australia', 'Australia', 'Australia', '1969-8-31')
# (17811, 'Female', 'Alicia Hoy', 'WATTLE GLEN', 'Victoria', 'Australia', 'Australia', '1985-10-15')
# (18067, 'Male', 'Rory Koerstz', 'MOUNT MCKENZIE', 'South Australia', 'Australia', 'Australia', '1941-10-26')
# (18263, 'Male', 'Callum Semmens', 'RURAL VIEW', 'Queensland', 'Australia', 'Australia', '1978-6-1')
# (18309, 'Male', 'Michael Vogt', 'FYANS CREEK', 'Victoria', 'Australia', 'Australia', '1992-1-7')
# (18470, 'Male', 'Zac Pryor', 'GOSFORD', 'New South Wales', 'Australia', 'Australia', '1969-3-12')
# (18493, 'Male', 'George Kevin', 'TASCOTT', 'New South Wales', 'Australia', 'Australia', '1994-9-27')
# (18714, 'Male', 'Ashton Aitken', 'PINWERNYING', 'Western Australia', 'Australia', 'Australia', '1972-8-13')
# (18887, 'Female', 'Zara Castleton', 'BOOROLITE', 'Victoria', 'Australia', 'Australia', '1978-11-25')
# (19082, 'Male', 'Matthew Denman', 'RANSOME', 'Queensland', 'Australia', 'Australia', '1939-4-6')
# (19207, 'Male', 'Luke Casimaty', 'KURRACA', 'Victoria', 'Australia', 'Australia', '1991-1-19')
# (19404, 'Male', "Cody O'Hea", 'WYNNUM', 'Queensland', 'Australia', 'Australia', '1997-6-10')
# (19534, 'Female', 'Leah Martin', 'TOOBORAC', 'Victoria', 'Australia', 'Australia', '1964-12-13')
# (19579, 'Female', 'Ava Reye', 'BARCALDINE', 'Queensland', 'Australia', 'Australia', '1949-10-16')
# (19726, 'Female', 'Victoria Daly', 'WATANOBBI', 'New South Wales', 'Australia', 'Australia', '1973-1-28')
# (27896, 'Male', 'Zachary McLeish', 'JACUP', 'Western Australia', 'Australia', 'Australia', '1973-10-17')
# (27945, 'Male', 'Charlie Stralia', 'SOFALA', 'New South Wales', 'Australia', 'Australia', '1974-5-20')
# (28076, 'Female', 'Alannah Onus', 'AVOCA', 'Tasmania', 'Australia', 'Australia', '1979-1-2')
# (28559, 'Male', 'Samuel Israel', 'YILKI', 'South Australia', 'Australia', 'Australia', '1968-12-7')
# (28690, 'Male', 'Leo Walcott', 'MILLCHESTER', 'Queensland', 'Australia', 'Australia', '1987-9-12')
# (28702, 'Female', 'Charli Lhotsky', 'DREWVALE', 'Queensland', 'Australia', 'Australia', '1966-6-30')
# (29041, 'Male', 'Logan Barling', 'LINDENOW', 'Victoria', 'Australia', 'Australia', '1937-11-14')
# (29278, 'Male', 'Justin Hartog', 'PINEVALE', 'Queensland', 'Australia', 'Australia', '1990-9-4')
# (29303, 'Male', 'Max Cohn', 'KIRTON POINT', 'South Australia', 'Australia', 'Australia', '1983-5-1')
# (29320, 'Male', 'Levi Barraclough', 'BLACKBUTT', 'New South Wales', 'Australia', 'Australia', '1938-10-14')
# (29475, 'Female', 'Madison Pocock', 'TUROSS', 'New South Wales', 'Australia', 'Australia', '1965-7-3')
# (29555, 'Male', 'Owen Edouard', 'GLEN MARTIN', 'New South Wales', 'Australia', 'Australia', '1992-7-3')
# (29593, 'Male', 'Liam Nettleton', 'BAKARA', 'South Australia', 'Australia', 'Australia', '1995-8-18')
# (29647, 'Female', 'Jessica Maynard', 'BRENDA', 'New South Wales', 'Australia', 'Australia', '1956-5-28')
# (29689, 'Female', 'Alexis Phillipps', 'BURWOOD HEIGHTS', 'New South Wales', 'Australia', 'Australia', '1966-8-28')
# (29812, 'Male', 'Marcus Napier', 'ST KILDA ROAD CENTRAL', 'Victoria', 'Australia', 'Australia', '1966-11-19')
# (29837, 'Female', 'Rebecca Jaques', 'MOUNT GEORGE', 'New South Wales', 'Australia', 'Australia', '1938-8-14')
# (29973, 'Female', 'Lauren Langton', 'DUCKINWILLA', 'Queensland', 'Australia', 'Australia', '1937-9-24')
# (30090, 'Male', 'George Farrer', 'PARK AVENUE', 'Queensland', 'Australia', 'Australia', '1960-10-7')
# (30278, 'Female', 'Madeleine Kiddle', 'JACANA', 'Victoria', 'Australia', 'Australia', '1945-9-12')
# (30428, 'Female', 'Sienna Conrick', 'EARLSTON', 'Victoria', 'Australia', 'Australia', '1999-12-1')
# (31086, 'Female', 'Kate Snowden', 'WITTENOOM', 'Western Australia', 'Australia', 'Australia', '1985-1-30')
# (31164, 'Male', 'Hunter Boehm', 'BOWES', 'Western Australia', 'Australia', 'Australia', '1948-6-15')
# (31236, 'Female', 'Abby Warburton', 'THREE BRIDGES', 'Victoria', 'Australia', 'Australia', '1959-8-8')
# (31288, 'Male', 'Adam Banning', 'CLAY WELLS', 'South Australia', 'Australia', 'Australia', '1988-8-28')
# (31374, 'Female', 'Ellie Griffin', 'ST AGNES', 'South Australia', 'Australia', 'Australia', '1960-12-2')
# (31721, 'Female', 'Alyssa Isaacs', 'GULFVIEW HEIGHTS', 'South Australia', 'Australia', 'Australia', '1961-1-19')
# (31784, 'Male', 'Zac Scherk', 'WAMBAN', 'New South Wales', 'Australia', 'Australia', '1968-1-2')
# (32037, 'Male', 'Aaron Knopwood', 'LAKE MOKOAN', 'Victoria', 'Australia', 'Australia', '1989-2-14')
# (32190, 'Female', 'Paige Lacey', 'DELAMERE', 'South Australia', 'Australia', 'Australia', '1954-10-28')
# (32259, 'Female', 'Ashley Dane?', 'SEVENHILL', 'South Australia', 'Australia', 'Australia', '1975-11-21')
# (32294, 'Male', 'Kai Nepean', 'RITE ISLAND', 'Queensland', 'Australia', 'Australia', '1948-8-4')
# (32455, 'Female', 'Charlotte Crane', 'MOSQUITO CREEK', 'Queensland', 'Australia', 'Australia', '1997-5-9')
# (32488, 'Male', 'Max Wylie', 'STAFFORD DC', 'Queensland', 'Australia', 'Australia', '1954-3-15')
# (32511, 'Male', 'Jasper Glassop', 'Woodford', 'New South Wales', 'Australia', 'Australia', '1964-2-29')
# (32538, 'Female', 'Eva Hazon', 'BOOMOODEERIE', 'New South Wales', 'Australia', 'Australia', '1986-7-20')
# (32939, 'Female', 'Alica Sizer', 'WONGULLA', 'South Australia', 'Australia', 'Australia', '1951-6-9')
# (33036, 'Male', 'Tyler Galvin', 'BYNG', 'New South Wales', 'Australia', 'Australia', '1959-7-31')
# (33205, 'Male', 'Andrew Hollway', 'CRYSTAL BROOK', 'Queensland', 'Australia', 'Australia', '1943-1-10')
# (33444, 'Male', 'Brodie Thirkell', 'CLAYTON', 'Victoria', 'Australia', 'Australia', '1968-1-9')
# (34081, 'Female', 'Imogen Permewan', 'FYANS CREEK', 'Victoria', 'Australia', 'Australia', '1939-5-8')
# (34126, 'Female', 'Victoria Tasman', 'MENINGIE EAST', 'South Australia', 'Australia', 'Australia', '1967-9-7')
# (34143, 'Male', 'John Gowlland', 'WARRANWOOD', 'Victoria', 'Australia', 'Australia', '1991-4-7')
# (34431, 'Male', 'Leo Badger', 'BEACONSFIELD', 'Western Australia', 'Australia', 'Australia', '1940-2-2')
# (34451, 'Male', 'Harry Edwin', 'GLADSTONE', 'New South Wales', 'Australia', 'Australia', '1972-11-1')
# (34462, 'Male', 'Tyson Tishler', 'TALAROO', 'Queensland', 'Australia', 'Australia', '1938-7-9')
# (34850, 'Female', "Caitlin O'Loghlin", 'BLUE VALE', 'New South Wales', 'Australia', 'Australia', '1960-11-30')
# (34915, 'Female', 'Kate Byles', 'MOUNT CRYSTAL', 'New South Wales', 'Australia', 'Australia', '1969-1-28')
# (35257, 'Female', 'Ella Oxenham', 'FERNHILL', 'New South Wales', 'Australia', 'Australia', '1970-2-20')
# (35479, 'Male', 'Jeremy Petre', 'COSSACK', 'Western Australia', 'Australia', 'Australia', '1978-6-8')
# (35703, 'Male', 'Rory Cotton', 'LUGARNO', 'New South Wales', 'Australia', 'Australia', '1961-12-14')
# (35733, 'Female', 'Charlotte Shaw', 'WAROONA', 'Western Australia', 'Australia', 'Australia', '1955-5-14')
# (35795, 'Male', 'Riley Clegg', 'MOYARRA', 'Victoria', 'Australia', 'Australia', '1995-8-7')
# (36112, 'Female', 'Emma Gepp', 'ANNUELLO', 'Victoria', 'Australia', 'Australia', '1937-2-12')
# (36336, 'Female', 'Anna Burston', 'DJARAWONG', 'Queensland', 'Australia', 'Australia', '1990-9-21')
# (36418, 'Female', 'Jorja Whitlam', 'MOUNT DAVID', 'New South Wales', 'Australia', 'Australia', '1946-2-18')
# (36507, 'Male', 'Joseph Paten', 'Golden Valley', 'Tasmania', 'Australia', 'Australia', '1955-3-23')
# (36816, 'Male', 'Luke Lazenby', 'LONGWARRY NORTH', 'Victoria', 'Australia', 'Australia', '1971-5-18')
# (36918, 'Male', 'Blake Mann', 'OWEN', 'South Australia', 'Australia', 'Australia', '1982-11-6')
# (37070, 'Female', 'Alyssa Hooker', 'WANGANUI', 'New South Wales', 'Australia', 'Australia', '1981-7-18')
# (37251, 'Male', 'Leo Scerri', 'GHERANG', 'Victoria', 'Australia', 'Australia', '1951-6-17')
# (37408, 'Male', 'Jaxon Rebell', 'TORRENS', 'Australian Capital Territory', 'Australia', 'Australia', '1975-10-11')
# (37580, 'Female', 'Mariam Baylee', 'TOMAHAWK', 'Tasmania', 'Australia', 'Australia', '1942-1-12')
# (37585, 'Female', 'Lauren Fink', 'YELTA', 'South Australia', 'Australia', 'Australia', '1944-4-17')
# (37802, 'Male', 'Luke Byron', 'SOUTH DUDLEY', 'Victoria', 'Australia', 'Australia', '1990-7-9')
# (37991, 'Male', 'Cooper Gillison', 'CARWELL', 'New South Wales', 'Australia', 'Australia', '1937-1-6')
# (38006, 'Male', 'Lachlan Postle', 'DYRAABA', 'New South Wales', 'Australia', 'Australia', '1955-10-29')
# (38036, 'Female', 'Kiara Schaw', 'UPPER YARRAMAN', 'Queensland', 'Australia', 'Australia', '1960-7-26')
# (38183, 'Male', 'Hunter Montagu', 'NEW ITALY', 'New South Wales', 'Australia', 'Australia', '1944-7-30')
# (38195, 'Female', 'Sara Roe', 'PAYNEDALE', 'Western Australia', 'Australia', 'Australia', '1972-11-22')
# (38212, 'Female', 'Stella Cain', 'WOOROONOOK', 'Victoria', 'Australia', 'Australia', '1985-1-28')
# (38558, 'Female', 'Audrey Bold', 'BOSTOBRICK', 'New South Wales', 'Australia', 'Australia', '1946-5-19')
# (38613, 'Male', 'Hamish Mason', 'Tacoma', 'New South Wales', 'Australia', 'Australia', '1988-3-16')
# (38865, 'Male', 'Christopher Edmund', 'WINDORAH', 'Queensland', 'Australia', 'Australia', '1948-8-17')
# (38950, 'Female', 'Hannah Edmond', 'ARTHUR RIVER', 'Tasmania', 'Australia', 'Australia', '1954-12-8')
# (39183, 'Male', 'Julian Gutteridge', 'KURMOND', 'New South Wales', 'Australia', 'Australia', '1973-4-25')
# (39246, 'Male', 'Darcy Falconer', 'MANDALAY', 'Queensland', 'Australia', 'Australia', '1974-10-20')
# (39268, 'Female', 'Madeleine Marx', 'KALLANGUR', 'Queensland', 'Australia', 'Australia', '1975-7-24')
# (39314, 'Male', 'Leo Ligar', 'LIGHT PASS', 'South Australia', 'Australia', 'Australia', '1985-4-20')
# (42603, 'Female', 'Amy Sawyer', 'CUSHNIE', 'Queensland', 'Australia', 'Australia', '2000-10-9')
# (42840, 'Female', 'Savannah Lansell', 'XANTIPPE', 'Western Australia', 'Australia', 'Australia', '1936-5-23')
# (42956, 'Male', 'Ben Raff', 'BARA', 'New South Wales', 'Australia', 'Australia', '1944-5-6')
# (43784, 'Male', 'Jeremy Iliffe', 'SNOWTOWN', 'South Australia', 'Australia', 'Australia', '1951-3-19')
# (43798, 'Female', 'Rachel Welch', 'AMAMOOR', 'Queensland', 'Australia', 'Australia', '1966-1-11')
# (43840, 'Female', 'Rose Vlamingh', 'OATLANDS', 'Tasmania', 'Australia', 'Australia', '1950-1-19')
# (44080, 'Female', 'Rachel Baldwin', 'Brighton', 'Victoria', 'Australia', 'Australia', '1954-1-20')
# (44195, 'Male', 'Brayden Topp', 'LOWER MANGROVE', 'New South Wales', 'Australia', 'Australia', '1984-1-9')
# (44207, 'Female', 'Stella Sternberg', 'KESWICK TERMINAL', 'South Australia', 'Australia', 'Australia', '1984-3-16')
# (44301, 'Female', 'Annabelle Feetham', 'DUNNROCK', 'Queensland', 'Australia', 'Australia', '1947-10-4')
# (44493, 'Female', 'Jorja Colechin', 'JACKEYS MARSH', 'Tasmania', 'Australia', 'Australia', '1963-4-28')
# (44496, 'Male', 'Spencer Beach', 'MOUNT JOY', 'South Australia', 'Australia', 'Australia', '1949-9-28')
# (44728, 'Female', 'Abbey Remington', 'DIGGORA', 'Victoria', 'Australia', 'Australia', '1953-3-14')
# (44906, 'Male', 'Tyson Backhouse', 'MOUNT GAMBIER', 'South Australia', 'Australia', 'Australia', '1994-10-6')
# (45169, 'Female', 'Victoria Ness', 'GLENROY', 'Queensland', 'Australia', 'Australia', '1990-4-4')
# (45172, 'Female', 'Audrey Crooke', 'SCOPUS', 'Tasmania', 'Australia', 'Australia', '1986-5-25')
# (45250, 'Male', 'Darcy Fryer', 'SACKVILLE', 'New South Wales', 'Australia', 'Australia', '1968-11-21')
# (45436, 'Female', 'Maya McIlveen', 'MILLFIELD', 'New South Wales', 'Australia', 'Australia', '1952-4-16')
# (45522, 'Male', 'Alexander Fenston', 'TIMBILLICA', 'New South Wales', 'Australia', 'Australia', '1985-4-9')
# (45781, 'Male', 'Bailey Coxen', 'PONTVILLE', 'Tasmania', 'Australia', 'Australia', '1946-2-27')
# (45814, 'Male', 'Declan Richard', 'SPRING HILL', 'New South Wales', 'Australia', 'Australia', '1968-4-5')
# (46155, 'Female', 'Alice Phillip', 'BOWES', 'Western Australia', 'Australia', 'Australia', '1956-2-16')
# (46917, 'Male', 'Jamie Price', 'MERU', 'Western Australia', 'Australia', 'Australia', '2000-1-3')
# (46996, 'Male', 'Jonathan Kempt', 'MURRAY ISLAND', 'Queensland', 'Australia', 'Australia', '1987-2-20')
# (47382, 'Female', 'Brooke Richardson', 'NORTHGATE', 'South Australia', 'Australia', 'Australia', '1955-5-2')
# (47518, 'Female', 'Alana Spencer', 'UNDULLAH', 'Queensland', 'Australia', 'Australia', '1946-5-13')
# (51648, 'Female', 'Jasmine Sellar', 'KYBUNGA', 'South Australia', 'Australia', 'Australia', '1989-6-11')
# (51649, 'Male', 'Toby Batchelor', 'YANDINA', 'Queensland', 'Australia', 'Australia', '1958-2-26')
# (51718, 'Female', 'Phoebe Voss', 'HACKNEY', 'South Australia', 'Australia', 'Australia', '1938-7-25')
# (52435, 'Male', 'Charles Kenneally', 'YADBORO', 'New South Wales', 'Australia', 'Australia', '1956-2-29')
# (52536, 'Male', 'Jamie Kavanagh', 'PINEWOOD', 'Victoria', 'Australia', 'Australia', '1987-2-16')
# (52694, 'Female', 'Grace Bidwill', 'Sheffield', 'Tasmania', 'Australia', 'Australia', '1972-5-21')
# (53168, 'Male', 'Dylan Monds', 'JOYNER', 'Queensland', 'Australia', 'Australia', '1959-4-5')
# (53260, 'Female', 'Keira Rowallan', 'MOUNT FRANKLIN', 'Victoria', 'Australia', 'Australia', '1936-5-9')
# (53318, 'Female', 'Grace Osburn', 'TOWNSON', 'Queensland', 'Australia', 'Australia', '1954-12-3')
# (53891, 'Male', 'Dominic Baylee', 'BINDA', 'New South Wales', 'Australia', 'Australia', '1944-2-10')
# (53920, 'Female', 'Jade Higgins', 'BUCKENBOWRA', 'New South Wales', 'Australia', 'Australia', '1986-3-27')
# (54089, 'Male', 'Jake Toft', 'THE GLEN', 'New South Wales', 'Australia', 'Australia', '1936-9-11')
# (54161, 'Male', 'Leo Voss', 'WOODY POINT', 'Queensland', 'Australia', 'Australia', '1992-6-24')
# (54535, 'Male', 'Joshua Nugan', 'CANNINDAH', 'Queensland', 'Australia', 'Australia', '1957-11-8')
# (54560, 'Female', 'Eden Bickford', 'ABINGDON DOWNS', 'Queensland', 'Australia', 'Australia', '1962-5-30')
# (54582, 'Female', 'Leah Fairbridge', 'LIMONITE', 'Victoria', 'Australia', 'Australia', '1978-9-15')
# (54627, 'Male', 'John Randall', 'TROWUTTA', 'Tasmania', 'Australia', 'Australia', '1968-5-25')
# (54704, 'Female', 'Alice Bartlett', 'TRAVANCORE', 'Victoria', 'Australia', 'Australia', '1951-10-22')
# (54752, 'Female', 'Natasha Morrison', 'SOUTH BUNBURY', 'Western Australia', 'Australia', 'Australia', '1965-12-16')
# (54794, 'Female', 'Georgia Barclay-Harvey', 'GARIE', 'New South Wales', 'Australia', 'Australia', '1965-8-9')
# (54987, 'Male', 'Isaac Sturt', 'MARMION', 'Western Australia', 'Australia', 'Australia', '1939-5-24')
# (55039, 'Male', 'James Connal', 'MOUNT MORIAC', 'Victoria', 'Australia', 'Australia', '1960-10-7')
# (55066, 'Male', 'Samuel Atherton', 'DOLLYS FLAT', 'New South Wales', 'Australia', 'Australia', '1942-2-14')
# (55084, 'Male', 'Angus Ten', 'PARAP', 'Northern Territory', 'Australia', 'Australia', '1963-12-3')
# (55411, 'Female', 'Lilian Stainforth', 'PHOENIX PARK', 'New South Wales', 'Australia', 'Australia', '1982-2-5')
# (55464, 'Female', 'Holly Mansour', 'PADDYS RIVER', 'New South Wales', 'Australia', 'Australia', '1981-11-16')
# (59422, 'Female', 'Amber Sykes', 'HILLGROVE', 'New South Wales', 'Australia', 'Australia', '1990-2-13')
# (59529, 'Female', 'Alice Blumenthal', 'FOREST GLEN', 'New South Wales', 'Australia', 'Australia', '1992-5-28')
# (59842, 'Male', 'Lucas McClure', 'BLETCHINGTON', 'New South Wales', 'Australia', 'Australia', '1939-1-19')
# (59961, 'Male', 'Harry Hambly', 'GALORE', 'New South Wales', 'Australia', 'Australia', '1948-2-3')
# (60009, 'Female', 'Natasha Gall', 'TOWNSVILLE CITY', 'Queensland', 'Australia', 'Australia', '1989-10-12')
# (60088, 'Female', 'Evie Brownbill', 'PAGES FLAT', 'South Australia', 'Australia', 'Australia', '1982-6-2')
# (60150, 'Female', 'Jasmine Mackay', 'NORTHLAND CENTRE', 'Victoria', 'Australia', 'Australia', '1964-2-14')
# (60407, 'Male', 'Alexander Earp', 'POZIERES', 'Queensland', 'Australia', 'Australia', '1944-9-4')
# (60411, 'Female', 'Eliza Solly', 'HIGHBURY', 'Western Australia', 'Australia', 'Australia', '1938-10-15')
# (60454, 'Male', 'Toby Normanby', 'LOWER LEWIS PONDS', 'New South Wales', 'Australia', 'Australia', '1953-5-5')
# (60475, 'Male', 'Joel Sharwood', 'CUDLEE CREEK', 'South Australia', 'Australia', 'Australia', '1948-5-27')
# (60722, 'Male', 'Logan Dowie', 'KOOROOMOOL', 'Queensland', 'Australia', 'Australia', '1985-6-8')
# (60892, 'Male', 'Seth Soubeiran', 'MOOLORT', 'Victoria', 'Australia', 'Australia', '1964-1-24')
# (60995, 'Male', 'Matthew Caron', 'TUENA', 'New South Wales', 'Australia', 'Australia', '1955-9-17')
# (61546, 'Female', 'Alexis Heagney', 'COASTERS RETREAT', 'New South Wales', 'Australia', 'Australia', '1953-9-14')
# (61718, 'Female', 'Chloe Schlapp', 'ALLIGATOR CREEK', 'Queensland', 'Australia', 'Australia', '1956-6-1')
# (61773, 'Female', 'Gabrielle Kossak', 'CAROONA', 'New South Wales', 'Australia', 'Australia', '2001-4-22')
# (61776, 'Male', 'Mitchell Cockle', 'TALLOWWOOD RIDGE', 'New South Wales', 'Australia', 'Australia', '1954-7-6')
# (61825, 'Male', 'Kai Culley', 'ERSKINEVILLE', 'New South Wales', 'Australia', 'Australia', '1995-10-9')
# (61881, 'Female', 'Rose Budd', 'ALBERTON', 'Victoria', 'Australia', 'Australia', '1994-5-11')
# (61947, 'Female', 'Amber Tolmie', 'NORVAL', 'Victoria', 'Australia', 'Australia', '1996-12-15')
# (62017, 'Female', 'Grace Humphries', 'HASTINGS', 'Western Australia', 'Australia', 'Australia', '1954-9-21')
# (62035, 'Male', 'John Duesbury', 'TIARO', 'Queensland', 'Australia', 'Australia', '1952-3-18')
# (62038, 'Male', 'Henry Birdwood', 'HINDMARSH', 'South Australia', 'Australia', 'Australia', '1997-6-5')
# (62076, 'Male', 'Brock Edden', 'ORIELTON', 'Tasmania', 'Australia', 'Australia', '1945-12-3')
# (62125, 'Female', 'Ava Lowes', 'IVERAGH', 'Queensland', 'Australia', 'Australia', '1978-4-10')
# (62133, 'Male', 'Jonathan Fargher', 'GWABEGAR', 'New South Wales', 'Australia', 'Australia', '1996-4-27')
# (62163, 'Female', "Amelia O'Neil", 'POINT LEO', 'Victoria', 'Australia', 'Australia', '1961-9-22')
# (62416, 'Female', 'Isabelle Whitworth', 'EIMEO', 'Queensland', 'Australia', 'Australia', '1943-2-23')
# (62473, 'Female', 'Mary Baskerville', 'PORT GERMEIN', 'South Australia', 'Australia', 'Australia', '1966-9-3')
# (62537, 'Female', 'Lauren Nichols', 'WOOLOOMAN', 'Queensland', 'Australia', 'Australia', '1937-5-3')
# (62590, 'Male', 'Aiden Thirkell', 'ROMAINE', 'Tasmania', 'Australia', 'Australia', '1972-11-16')
# (63342, 'Male', 'Joel Spowers', 'KWEDA', 'Western Australia', 'Australia', 'Australia', '1971-10-6')
# (63597, 'Male', 'Darcy Penington', 'RIVERHILLS', 'Queensland', 'Australia', 'Australia', '1939-4-19')
# (63681, 'Male', 'Justin Grahamslaw', 'POSSUM BRUSH', 'New South Wales', 'Australia', 'Australia', '1936-4-27')
# (63807, 'Male', 'Ashton Bower', 'ALLAMBIE HEIGHTS', 'New South Wales', 'Australia', 'Australia', '1948-12-2')
# (63957, 'Female', 'Dakota Nixon-Smith', 'FORTHSIDE', 'Tasmania', 'Australia', 'Australia', '1991-1-13')
# (64017, 'Female', 'Ruby Sternberg', 'BRIGHTVIEW', 'Queensland', 'Australia', 'Australia', '1964-10-5')
# (64037, 'Male', 'Andrew Wilkie', 'WONGARBON', 'New South Wales', 'Australia', 'Australia', '1936-9-13')
# (64104, 'Female', 'Brooke Cascarret', 'COOTRA', 'South Australia', 'Australia', 'Australia', '1938-6-26')
# (64210, 'Male', 'Lucas De Garis', 'Sheffield', 'Tasmania', 'Australia', 'Australia', '1992-4-5')
# (64491, 'Male', 'Oliver McCloughry', 'MELBA', 'Australian Capital Territory', 'Australia', 'Australia', '1997-9-15')
# (64511, 'Female', 'Alice Gouger', 'ARGOON', 'Queensland', 'Australia', 'Australia', '1963-1-5')
# (64764, 'Male', 'Jacob Pelsaert', 'LESLEY', 'Western Australia', 'Australia', 'Australia', '1986-3-3')
# (64842, 'Male', 'Levi Strele', 'MOUNT OUSLEY', 'New South Wales', 'Australia', 'Australia', '1971-9-5')
# (64989, 'Female', 'Alice Moynihan', 'COMMISSIONERS CREEK', 'New South Wales', 'Australia', 'Australia', '1994-3-4')
# (65112, 'Female', 'Ebony Fairley', 'POINT TURTON', 'South Australia', 'Australia', 'Australia', '1951-9-3')
# (65163, 'Female', 'Abigail Considen', 'Beaufort', 'Victoria', 'Australia', 'Australia', '1954-1-19')
# (65180, 'Female', 'Maya Colvin', 'NORTHLAKES', 'Northern Territory', 'Australia', 'Australia', '1979-1-28')
# (65210, 'Female', 'Caitlin Spooner', 'DOWLINGVILLE', 'South Australia', 'Australia', 'Australia', '1948-11-8')
# (65269, 'Female', 'Scarlett Roach', 'BARWIDGEE', 'Victoria', 'Australia', 'Australia', '1941-1-24')
# (65283, 'Female', 'Jessica Latham', 'BUNGUNDARRA', 'Queensland', 'Australia', 'Australia', '1943-4-5')
# (65372, 'Male', 'Logan Iredale', 'LONG FLAT', 'Queensland', 'Australia', 'Australia', '1986-6-11')
# (65507, 'Female', 'Grace Deane', 'DARLING HEIGHTS', 'Queensland', 'Australia', 'Australia', '1979-5-7')
# (65544, 'Male', 'Dylan Smerd', 'LAKE MUIR', 'Western Australia', 'Australia', 'Australia', '1957-11-14')
# (65856, 'Male', 'Harrison Cantamessa', 'ARNOLD WEST', 'Victoria', 'Australia', 'Australia', '1955-10-28')
# (66352, 'Female', 'Bethany Hose', 'NULSEN', 'Western Australia', 'Australia', 'Australia', '1959-3-10')
# (66610, 'Female', 'Charli Frost', 'FERNSHAW', 'Victoria', 'Australia', 'Australia', '1982-2-9')
# (66677, 'Female', "Abby O'Mahony", 'TINGHA', 'New South Wales', 'Australia', 'Australia', '1978-1-16')
# (67066, 'Male', 'Alexander Newling', 'MOUNT RICHON', 'Western Australia', 'Australia', 'Australia', '1950-9-9')
# (67157, 'Male', 'Levi Knox', 'KIAMA DOWNS', 'New South Wales', 'Australia', 'Australia', '1937-4-4')
# (67217, 'Male', 'Aiden De Burgh', 'JUBILEE HEIGHTS', 'Queensland', 'Australia', 'Australia', '1983-3-4')
# (67369, 'Female', 'Rachel Gairdner', 'ZADOWS LANDING', 'South Australia', 'Australia', 'Australia', '1997-1-26')
# (67380, 'Female', 'Alexis Melville', 'HORSNELL GULLY', 'South Australia', 'Australia', 'Australia', '1958-3-13')
# (67398, 'Male', 'Harrison Trigg', 'MONASH', 'Australian Capital Territory', 'Australia', 'Australia', '1998-2-4')
# (67455, 'Male', 'Logan Armytage', 'GREEN HILLS', 'New South Wales', 'Australia', 'Australia', '1993-9-15')
# (67481, 'Male', 'Beau Fitzgerald', 'RED BANKS', 'South Australia', 'Australia', 'Australia', '1954-1-17')
# (67744, 'Male', 'Elijah Newbery', 'PUNCHBOWL', 'Tasmania', 'Australia', 'Australia', '1944-7-3')
# (68000, 'Male', 'Aaron Sasse', 'CANNING CREEK', 'Queensland', 'Australia', 'Australia', '1973-1-22')
# ...
# (2081694, 'Female', 'Poppy Wesch', 'Tampa', 'Florida', 'United States', 'North America', '1937-9-27')
# (2081697, 'Female', 'Alyssa Worrall', 'Rochester', 'New York', 'United States', 'North America', '1988-1-1')
# (2081773, 'Male', 'Ajdin Sandberg', 'Pleasantville (Atlantic)', 'New Jersey', 'United States', 'North America', '1940-2-19')
# (2081995, 'Male', 'Atila Garica', 'Fort Myers', 'Florida', 'United States', 'North America', '1972-9-14')
# (2082022, 'Female', 'Melanie Baumgaertner', 'Elmsford', 'New Jersey', 'United States', 'North America', '1943-2-6')
# (2082135, 'Male', 'Alexander Kortig', 'Spokane', 'Washington', 'United States', 'North America', '1942-9-5')
# (2082326, 'Female', 'Sarah Busch', 'Denver', 'Colorado', 'United States', 'North America', '1994-1-22')
# (2082335, 'Male', 'Brigliador Morel', 'Palo Alto', 'California', 'United States', 'North America', '1981-8-10')
# (2082534, 'Male', 'Sergiusz Duda', 'Maple Shade', 'New Jersey', 'United States', 'North America', '1982-8-8')
# (2082719, 'Female', 'Linde Olsen', 'Unionville', 'Missouri', 'United States', 'North America', '1987-11-28')
# (2082954, 'Female', 'Jakobine Mikaelsen', 'Spokane', 'Washington', 'United States', 'North America', '1938-11-28')
# (2082962, 'Male', 'Henry Harris', 'Baton Rouge', 'Louisiana', 'United States', 'North America', '1998-5-6')
# (2082986, 'Female', 'Elcira Velasco', 'Edison', 'New Jersey', 'United States', 'North America', '1986-4-28')
# (2082991, 'Male', 'Michael Ward', 'Baltimore', 'Maryland', 'United States', 'North America', '1980-11-15')
# (2083305, 'Female', 'Michelle Kvamme', 'Phoenix', 'Arizona', 'United States', 'North America', '1987-12-27')
# (2083307, 'Female', 'Maren Kleist', 'Kattskill Bay', 'New York', 'United States', 'North America', '1945-12-26')
# (2083381, 'Female', 'Eusebia Valladares', 'Moravia', 'New York', 'United States', 'North America', '1945-2-22')
# (2083421, 'Male', 'Nuka Nielsen', 'Waterbury', 'Vermont', 'United States', 'North America', '1986-3-17')
# (2083482, 'Male', 'Jasper Moore', 'Independence', 'Ohio', 'United States', 'North America', '1952-1-3')
# (2083496, 'Female', 'Brigitte Strauss', 'Raleigh', 'North Carolina', 'United States', 'North America', '1982-7-20')
# (2083610, 'Male', 'Adel Gustafsson', 'Greensboro', 'North Carolina', 'United States', 'North America', '1973-10-16')
# (2083637, 'Female', 'Jasminka Kovacevic', 'Menasha', 'Wisconsin', 'United States', 'North America', '1996-6-6')
# (2083671, 'Male', 'Henrik Petrussen', 'Philadelphia', 'Pennsylvania', 'United States', 'North America', '1980-9-25')
# (2084056, 'Male', 'Julian Berggren', 'Hanover', 'Maryland', 'United States', 'North America', '1995-11-1')
# (2084090, 'Female', 'Sabine Beike', 'Mountain View', 'Wyoming', 'United States', 'North America', '1985-9-14')
# (2084140, 'Male', 'Zdenek Smutný', 'Fort Smith', 'Montana', 'United States', 'North America', '1968-3-22')
# (2084343, 'Male', 'Barry Hughes', 'Charlotte', 'North Carolina', 'United States', 'North America', '1996-3-11')
# (2084403, 'Female', 'Edaline Mascarenas', 'Holland', 'Ohio', 'United States', 'North America', '1996-6-17')
# (2084813, 'Female', 'Jana \x8aimunovic', 'Huntsville', 'Alabama', 'United States', 'North America', '1973-5-24')
# (2084881, 'Male', 'Václav Bílek', 'Allen', 'Nebraska', 'United States', 'North America', '1978-5-27')
# (2085017, 'Female', 'Inger Møller', 'Sunnyside', 'Washington', 'United States', 'North America', '1968-11-2')
# (2085055, 'Male', 'Marc Abrahamsson', 'East Hartford', 'Connecticut', 'United States', 'North America', '1996-3-6')
# (2085404, 'Male', 'William Higgins', 'Waltham', 'Massachusetts', 'United States', 'North America', '1991-11-11')
# (2085857, 'Female', 'Elisabeth Berthelsen', 'Watertown', 'New York', 'United States', 'North America', '1941-1-2')
# (2086280, 'Male', 'Michael Frei', 'Louisville', 'Kentucky', 'United States', 'North America', '1958-6-17')
# (2086544, 'Female', 'Andrea Trommler', 'Manassas', 'Virginia', 'United States', 'North America', '1939-2-10')
# (2086548, 'Male', 'Augustyn Czerwinski', 'Schiller Park', 'Illinois', 'United States', 'North America', '1968-6-9')
# (2086596, 'Male', 'Minik Kreutzmann', 'Lexington', 'Kentucky', 'United States', 'North America', '1953-5-20')
# (2086639, 'Male', 'Denniz Nilsson', 'Southfield', 'Michigan', 'United States', 'North America', '1948-4-5')
# (2086673, 'Male', 'Jozo Vukovic', 'Greenville', 'South Carolina', 'United States', 'North America', '1961-3-2')
# (2086759, 'Male', 'Andreas Wechsler', 'Layton', 'Utah', 'United States', 'North America', '1936-9-25')
# (2086891, 'Female', 'Hrvojka Ba\x9aic', 'Fort Wayne', 'Indiana', 'United States', 'North America', '1942-6-2')
# (2087018, 'Female', 'Madeleine Paiement', 'Las Vegas', 'Nevada', 'United States', 'North America', '1964-1-21')
# (2087058, 'Female', 'Klara Rutkowska', 'Crete', 'Nebraska', 'United States', 'North America', '1994-8-31')
# (2087288, 'Male', 'Miki Filemonsen', 'Albany', 'New York', 'United States', 'North America', '1963-9-6')
# (2087433, 'Female', 'Eli\x9aka Klofácová', 'Gibsonia', 'Pennsylvania', 'United States', 'North America', '1944-3-26')
# (2087477, 'Female', 'Klaudia Ebersbach', 'Idaho Falls', 'Idaho', 'United States', 'North America', '1995-11-26')
# (2087620, 'Female', 'Maren Pettersen', 'Kansas City', 'Missouri', 'United States', 'North America', '1943-11-18')
# (2087679, 'Female', 'Iveta Stejskalová', 'Oklahoma City', 'Oklahoma', 'United States', 'North America', '1996-11-11')
# (2087843, 'Male', 'Ole Dybvik', 'Buffalo', 'New York', 'United States', 'North America', '1984-1-24')
# (2087852, 'Male', 'Ali Koerstz', 'Dallas', 'Texas', 'United States', 'North America', '1965-12-23')
# (2087937, 'Female', 'Sofie Kristensen', 'Houston', 'Texas', 'United States', 'North America', '1963-4-19')
# (2087983, 'Male', 'Tim Egger', 'Clearwater', 'Minnesota', 'United States', 'North America', '1991-8-27')
# (2088176, 'Male', 'Carlos Young', 'Virginia Beach', 'Virginia', 'United States', 'North America', '1971-9-14')
# (2088314, 'Male', 'Lloyd Johnson', 'Frisco', 'Texas', 'United States', 'North America', '1976-7-13')
# (2088405, 'Male', 'Tin Vidakovic', 'Murfreesboro', 'North Carolina', 'United States', 'North America', '1951-7-10')
# (2088559, 'Male', 'Coby Cunningham', 'Tampa', 'Florida', 'United States', 'North America', '1969-5-15')
# (2088572, 'Female', 'Coretta McDonald', 'Sudbury', 'Massachusetts', 'United States', 'North America', '1987-7-26')
# (2088614, 'Female', 'Barbara Sawicka', 'Miami', 'Florida', 'United States', 'North America', '1935-11-28')
# (2088753, 'Female', 'Rubí Bañuelos', 'Southfield', 'Michigan', 'United States', 'North America', '1979-4-30')
# (2088822, 'Male', 'Villiam Sandberg', 'New York', 'New York', 'United States', 'North America', '1974-6-11')
# (2088972, 'Female', 'Eva Brandt', 'Ephraim', 'Utah', 'United States', 'North America', '1935-5-19')
# (2088994, 'Male', 'Leon Wulf', 'Tampa', 'Florida', 'United States', 'North America', '1952-9-23')
# (2089159, 'Male', 'Jean Thériault', 'Madison', 'Wisconsin', 'United States', 'North America', '1941-9-21')
# (2089160, 'Male', 'Jindrich Andr\x9a', 'Newark', 'New Jersey', 'United States', 'North America', '1975-10-11')
# (2089262, 'Male', 'Jindrich Kopecek', 'Humansville', 'Missouri', 'United States', 'North America', '1936-10-19')
# (2089265, 'Female', 'Nivi Karlsen', 'Southfield', 'Michigan', 'United States', 'North America', '2001-3-2')
# (2089653, 'Male', 'Max Unger', 'Newark', 'Delaware', 'United States', 'North America', '1964-5-23')
# (2089881, 'Female', 'Veronika Kubínková', 'Tulsa', 'Oklahoma', 'United States', 'North America', '1992-3-4')
# (2089914, 'Male', 'Duje Debeljak', 'Waterloo', 'New York', 'United States', 'North America', '1980-2-27')
# (2090023, 'Male', 'Delfina Solórzano', 'Fayetteville', 'North Carolina', 'United States', 'North America', '1955-10-13')
# (2090406, 'Male', 'Franciszek Sawicki', 'Columbus', 'Ohio', 'United States', 'North America', '1956-11-12')
# (2090423, 'Female', 'Brigitte Archambault', 'Keaau', 'Hawaii', 'United States', 'North America', '1971-5-7')
# (2090432, 'Female', 'Heike Himmel', 'Olivette', 'Missouri', 'United States', 'North America', '1985-4-8')
# (2090514, 'Female', 'Gail Kuhn', 'Hyannis', 'Massachusetts', 'United States', 'North America', '1963-8-8')
# (2090571, 'Female', 'Emma Søvik', 'Aberdeen', 'Washington', 'United States', 'North America', '1942-4-27')
# (2090623, 'Female', 'Johanne Nielsen', 'Owensboro', 'Kentucky', 'United States', 'North America', '1944-6-2')
# (2090627, 'Female', 'Lorena Vukelic', 'Miami', 'Florida', 'United States', 'North America', '1989-6-14')
# (2090990, 'Female', 'Lilly Gratton', 'Oak Lawn', 'Illinois', 'United States', 'North America', '1958-6-26')
# (2091158, 'Female', 'Mary Sullivan', 'Detroit', 'Michigan', 'United States', 'North America', '1954-3-28')
# (2091204, 'Male', 'Knud Davidsen', 'Winston Salem', 'North Carolina', 'United States', 'North America', '1935-10-11')
# (2091352, 'Female', 'Alina Wilson', 'Spur', 'Texas', 'United States', 'North America', '1988-12-3')
# (2091659, 'Male', 'Petr Pokorný', 'Mattoon', 'Illinois', 'United States', 'North America', '1967-1-24')
# (2091678, 'Male', 'Vegar Ali', 'Wilmington', 'Delaware', 'United States', 'North America', '1946-4-9')
# (2091767, 'Male', 'Kasper Hope', 'Murray', 'Utah', 'United States', 'North America', '1998-1-26')
# (2091926, 'Male', 'Jaroslav Lebeda', 'Indianapolis', 'Indiana', 'United States', 'North America', '1973-5-25')
# (2092033, 'Male', 'Mathew Forbes', 'Anniston', 'Alabama', 'United States', 'North America', '1995-10-7')
# (2092037, 'Female', 'Tiegan McIntyre', 'Liverpool', 'New York', 'United States', 'North America', '1989-1-7')
# (2092053, 'Female', 'Zorica Lucic', 'Hayward', 'California', 'United States', 'North America', '1950-10-21')
# (2092310, 'Female', 'Lucyna Sobczak', 'Rosedale', 'Louisiana', 'United States', 'North America', '1948-1-11')
# (2092398, 'Male', 'Austin Hunter', 'Shelbyville', 'Indiana', 'United States', 'North America', '2001-3-25')
# (2092412, 'Female', 'Stanka Petkovic', 'Los Angeles', 'California', 'United States', 'North America', '1951-12-29')
# (2092654, 'Male', 'Rasmus Zeeb', 'Hempstead', 'Texas', 'United States', 'North America', '1946-7-31')
# (2092935, 'Female', 'Zurie Ruel', 'Fuquay Varina', 'North Carolina', 'United States', 'North America', '1986-9-19')
# (2092966, 'Female', 'Dalmacia Márquez', 'Tacoma', 'Washington', 'United States', 'North America', '1973-10-24')
# (2092988, 'Male', 'Ludvig Lundblad', 'Santa Monica', 'California', 'United States', 'North America', '1951-8-16')
# (2093071, 'Male', 'Scott Stewart', 'Englewood', 'Colorado', 'United States', 'North America', '1959-2-23')
# (2093086, 'Male', 'Gerald Johansson', 'Palo Alto', 'California', 'United States', 'North America', '1958-1-2')
# (2093175, 'Male', 'Lechoslaw Jasinski', 'Louisville', 'Kentucky', 'United States', 'North America', '1940-8-31')
# (2093340, 'Female', 'Betty Houston', 'Freeport', 'Illinois', 'United States', 'North America', '1998-2-22')
# (2093665, 'Female', 'Vesna Kolar', 'Red Bank', 'New Jersey', 'United States', 'North America', '2002-1-3')
# (2093741, 'Female', 'Jarmila Hájková', 'Rochelle Park', 'New Jersey', 'United States', 'North America', '1945-3-11')
# (2093929, 'Female', 'Lucie Hrebacková', 'Louisville', 'Kentucky', 'United States', 'North America', '1954-8-10')
# (2094015, 'Male', 'Malik Filemonsen', 'Wallkill', 'New York', 'United States', 'North America', '1956-2-18')
# (2094190, 'Male', 'Cencio Ruelas', 'Farmingdale', 'New York', 'United States', 'North America', '1947-3-26')
# (2095098, 'Male', 'Levi Quinn', 'Osage', 'Oklahoma', 'United States', 'North America', '1950-3-23')
# (2095252, 'Female', 'Mia Torreggiani', 'Youngstown', 'Ohio', 'United States', 'North America', '1973-5-21')
# (2095256, 'Female', 'Alannah McAuley', 'West Alexander', 'Pennsylvania', 'United States', 'North America', '1941-6-2')
# (2095309, 'Male', 'Robert Rothschild', 'Houston', 'Texas', 'United States', 'North America', '1935-6-3')
# (2095351, 'Female', 'Gemma Wentworth', 'Wishon', 'California', 'United States', 'North America', '1941-2-18')
# (2095590, 'Male', 'René Pitre', 'Newburg', 'Texas', 'United States', 'North America', '1992-1-27')
# (2095742, 'Female', 'Michelle Krüger', 'Gooding', 'Idaho', 'United States', 'North America', '1942-8-3')
# (2095952, 'Female', 'Ylva Abrahamsson', 'Nashville', 'Tennessee', 'United States', 'North America', '1983-10-9')
# (2095996, 'Female', 'Novalie Nordström', 'San Francisco', 'California', 'United States', 'North America', '1945-8-25')
# (2096004, 'Male', 'Kacper Wysocki', 'Hartford', 'Connecticut', 'United States', 'North America', '1995-6-9')
# (2096104, 'Female', 'Madicken Lundin', 'Marquette', 'Michigan', 'United States', 'North America', '1983-2-6')
# (2096178, 'Female', 'Jessica Thorn', 'Indianapolis', 'Indiana', 'United States', 'North America', '1947-8-8')
# (2096214, 'Female', 'Mary Crommelin', 'Ardmore', 'Pennsylvania', 'United States', 'North America', '2001-9-9')
# (2096292, 'Male', 'Scoville Duclos', 'De Bary', 'Florida', 'United States', 'North America', '1953-7-13')
# (2096435, 'Male', 'Drew Ross', 'Seattle', 'Washington', 'United States', 'North America', '1935-9-21')
# (2096472, 'Female', 'Laure Mainville', 'Anaheim', 'California', 'United States', 'North America', '1993-6-4')
# (2096492, 'Male', 'Roberto Kne\x9eevic', 'Washington', 'Washington DC', 'United States', 'North America', '1961-10-2')
# (2096777, 'Male', 'Yves Busson', 'Irvine', 'California', 'United States', 'North America', '1965-5-6')
# (2097018, 'Female', 'Thérèse Lapresse', 'Simpsonville', 'South Carolina', 'United States', 'North America', '1968-5-29')
# (2097084, 'Female', 'Markéta Zdenková', 'Felton', 'Delaware', 'United States', 'North America', '1951-10-31')
# (2097135, 'Female', 'Minea Nordin', 'Cambridge', 'Massachusetts', 'United States', 'North America', '1937-10-9')
# (2097619, 'Female', 'Cika Dujmovic', 'Schaumburg', 'Illinois', 'United States', 'North America', '2002-2-18')
# (2097629, 'Male', 'Marko Holtzmann', 'Longview', 'Texas', 'United States', 'North America', '1991-6-5')
# (2097966, 'Female', 'Jaroslava Petrlíková', 'Westerville', 'Ohio', 'United States', 'North America', '1997-8-1')
# (2098097, 'Female', 'Gemma Trompf', 'Rocky Mount', 'North Carolina', 'United States', 'North America', '1979-9-25')
# (2098140, 'Male', 'Leonardo Murray', 'Garden City', 'New York', 'United States', 'North America', '1986-11-11')
# (2098212, 'Female', 'Zdenka Jirkovská', 'Burnsville', 'Mississippi', 'United States', 'North America', '1939-12-13')
# (2098223, 'Female', 'Hansine Davidsen', 'Westerville', 'Ohio', 'United States', 'North America', '1987-11-2')
# (2098404, 'Female', 'Lenka Cadilová', 'Pump Station Three', 'Alaska', 'United States', 'North America', '1971-12-2')
# (2098879, 'Male', 'Isaac Blom', 'Bakersfield', 'California', 'United States', 'North America', '1974-7-15')
# (2098944, 'Female', 'Emmeline Daviau', 'Reston', 'Maryland', 'United States', 'North America', '1978-4-1')
# (2099252, 'Female', 'Angelika Nowicka', 'Los Angeles', 'California', 'United States', 'North America', '2001-1-27')
# (2099258, 'Female', 'Zorica Cerkez', 'Metropolis', 'Illinois', 'United States', 'North America', '1993-7-15')
# (2099383, 'Female', 'Yseult Lacharité', 'Indianapolis', 'Indiana', 'United States', 'North America', '2000-2-24')
# (2099497, 'Female', 'Borislava Hrvatin', 'Lorton', 'Virginia', 'United States', 'North America', '1947-3-25')
# (2099600, 'Female', 'Denisa Du\x9aková', 'Houston', 'Texas', 'United States', 'North America', '1936-3-25')
# (2099618, 'Male', 'Justin Solórzano', 'Mclean', 'Virginia', 'United States', 'North America', '1992-2-16')
# (2099758, 'Male', 'Svend Petrussen', 'Wilmington', 'North Carolina', 'United States', 'North America', '1937-11-9')
# (2099862, 'Female', 'Lorenza Rush', 'Riverside', 'California', 'United States', 'North America', '1937-10-12')
# (2099937, 'Male', 'Zygmunt Kaminski', 'Bloomfield Township', 'Michigan', 'United States', 'North America', '1965-8-18')

# %%
# exchange table creation
mycursor.execute('''CREATE TABLE IF NOT EXISTS exchange_details(
                  Date VARCHAR(255),
                  Currency_Code VARCHAR(255),
                  Exchange FLOAT
                  )''')
print("Table Created successfully")
# Out:
# Table Created successfully

# %%
# insert values into exchange table
insert_query ='''INSERT INTO customer_sales.exchange_details(
                  Date,
                Currency_Code,
                  Exchange)
                  VALUES (%s, %s, %s)'''
for index, row in df_exchange.iterrows():
    mycursor.execute(insert_query, (
        row['Date'], row['Currency Code'],
        row['Exchange']
        
    ))

print("Inserted successfully")
# Out:
# Inserted successfully

# %%
# create Products table 
mycursor.execute('''CREATE TABLE IF NOT EXISTS customer_sales.product_details(
                  ProductKey INT,
                  Product_Name VARCHAR(255),
                  Brand VARCHAR(255),
                  Color VARCHAR(255),
                  Unit_Cost_USD FLOAT,
                  Unit_Price_USD FLOAT,
                  Subcategory VARCHAR(255),
                  CategoryKey VARCHAR(255),
                  Category VARCHAR(255)
                  )''')
print("Table Created successfully")
# Out:
# Table Created successfully

# %%
#insert values into Products table
insert_query ='''INSERT INTO customer_sales.product_details(
                  ProductKey,
                  Product_Name,
                  Brand,
                  Color,
                  Unit_Cost_USD,
                  Unit_Price_USD,
                  Subcategory,
                  CategoryKey,
                  Category)
                  VALUES (%s, %s, %s, %s, %s, %s, %s, %s,%s)'''
for index, row in df_products.iterrows():
    mycursor.execute(insert_query, (
        row['ProductKey'], row['Product Name'],
        row['Brand'], row['Color'], 
        row['Unit Cost USD'],  
        row['Unit Price USD'], row['Subcategory'], 
        row['CategoryKey'], row['Category']
        
    ))

print("Inserted successfully")
# Out:
# Inserted successfully

# %%
#sales table creation
mycursor.execute('''CREATE TABLE IF NOT EXISTS customer_sales.sales_details(
                  Order_Number INT,
                  Line_Item INT,
                  Order_Date VARCHAR(255),
                  Delivery_Date VARCHAR(255),
                  CustomerKey INT,
                  StoreKey INT,
                  ProductKey INT,
                  Quantity INT,
                  Currency_Code VARCHAR(255)
                  )''')
print("Table Created successfully")
# Out:
# Table Created successfully

# %%
#insert values into sales table
insert_query ='''INSERT INTO customer_sales.sales_details(
                  Order_Number,
                  Line_Item,
                  Order_Date,
                  Delivery_Date,
                  CustomerKey,
                  StoreKey,
                  ProductKey,
                  Quantity,
                  Currency_Code)
                  VALUES (%s, %s, %s, %s, %s, %s, %s, %s,%s)'''
for index, row in df_sales.iterrows():
    mycursor.execute(insert_query, (
        row['Order Number'], row['Line Item'],
        row['Order Date'], row['Delivery Date'], 
        row['CustomerKey'], 
        row['StoreKey'], row['ProductKey'], 
        row['Quantity'], row['Currency Code']
        
    ))

print("Inserted successfully")
# Out:
# Inserted successfully

# %%
#store table creation
mycursor.execute('''CREATE TABLE IF NOT EXISTS customer_sales.stores_details(
                  StoreKey INT,
                  Country VARCHAR(255),
                  State VARCHAR(255),
                  Square_Meters FLOAT,
                  Open_Date VARCHAR(255)
                  )''')
print("Table Created successfully")
# Out:
# Table Created successfully

# %%
##insert values into Store table
insert_query ='''INSERT INTO customer_sales.stores_details(
                 StoreKey,
                  Country,
                  State,
                  Square_Meters,
                  Open_Date)
                  VALUES (%s, %s, %s, %s, %s)'''
for index, row in df_stores.iterrows():
    mycursor.execute(insert_query, (
        row['StoreKey'], row['Country'],
        row['State'], row['Square Meters'], 
        row['Open Date']
        
    ))
print("Inserted successfully")
# Out:
# Inserted successfully
